# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  0.428703 -1.829685 -0.172629
# b       NaN       NaN       NaN
# c -0.801928  0.316973  0.498229
# d -1.417738 -1.543666  0.821623
# e       NaN       NaN       NaN
# f  2.219184  1.843259 -0.121500
#
#
# Dropped DataFrame
#          one       two     three
# a  0.428703 -1.829685 -0.172629
# c -0.801928  0.316973  0.498229
# d -1.417738 -1.543666  0.821623
# f  2.219184  1.843259 -0.121500

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.288059  0.609706  0.653364
# b       NaN       NaN       NaN
# c -1.154431  2.067391 -0.906263
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.288059  0.609706  0.653364
# b  0.000000  0.000000  0.000000
# c -1.154431  2.067391 -0.906263

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  0.608323  1.019872  1.171121
# b       NaN       NaN       NaN
# c -1.443301  1.765916  0.534912
# d -0.961837 -0.276714 -0.143903
# e       NaN       NaN       NaN
# f  1.791715 -0.686117  1.057159
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df = pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n", df)
print("\nNaN - Filled with Backward values:\n")
print(df.bfill())
# Out:
# Original Dataframe:
#          one       two     three
# a -0.400362  0.973243  0.288538
# b       NaN       NaN       NaN
# c -1.727050 -0.999594 -0.735555
# d  1.142803 -0.577983  1.026233
# e       NaN       NaN       NaN
# f -0.392314 -0.119012 -0.937497
#
# NaN - Filled with Backward values:
#
#         one       two     three
# a -0.400362  0.973243  0.288538
# b -1.727050 -0.999594 -0.735555
# c -1.727050 -0.999594 -0.735555
# d  1.142803 -0.577983  1.026233
# e -0.392314 -0.119012 -0.937497
# f -0.392314 -0.119012 -0.937497
