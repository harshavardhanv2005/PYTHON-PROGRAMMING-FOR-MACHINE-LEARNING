# %%
import pandas as pd
df =pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
emp=pd.Series(['Parker','John','Smith','William'])
id=pd.Series([102,107,109,114])   
frame={'Emp':emp,'ID':id}
result=pd.DataFrame(frame)
print("\n series to Data frame\n")
print(result)
# Out:
#  series to Data frame
#
#        Emp   ID
# 0   Parker  102
# 1     John  107
# 2    Smith  109
# 3  William  114

# %%
print("\n Extracting one column:\n")
print(['Emp'])
# Out:
#  Extracting one column:
#
# ['Emp']

# %%
print("\nAdding new column:\n")
result['Age']=pd.Series([35,24,40,38])
print(result)
# Out:
# Adding new column:
#
#        Emp   ID  Age
# 0   Parker  102   35
# 1     John  107   24
# 2    Smith  109   40
# 3  William  114   38

# %%
print("\n Deleting one column:\n")
del result['Age']
print(result)
# Out:
#  Deleting one column:
#
#        Emp   ID
# 0   Parker  102
# 1     John  107
# 2    Smith  109
# 3  William  114

# %%
print("\n Extracting the third row:\n")
print(result.10[2])
# Out:
#   Cell In[69], line 2
#     print(result.10[2])
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("\n sline rows;\n",result[1:3])
# Out:
#  sline rows;
#       Emp   ID
# 1   John  107
# 2  Smith  109

# %%
d2=pd.Dataframe([['Date',123],['Mark',43]])
columns=['Emp','ID']
print(["\n Adding new row values:\n"]),Pd
contact([result,d2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 d2=pd.Dataframe([['Date',123],['Mark',43]])
#       2 columns=['Emp','ID']
#       3 print(["\n Adding new row values:\n"]),Pd
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
print("\n Deleting Partal row:\n",result.drop(1))
# Out:
#  Deleting Partal row:
#         Emp   ID
# 0   Parker  102
# 2    Smith  109
# 3  William  114
